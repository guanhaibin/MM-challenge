# %%
#source("http://bioconductor.org/biocLite.R")
#biocLite('mixOmics')
library(mixOmics)

# %%
emtab_entrez_df=t(read.csv('datasets/microarray/EMTAB4032entrezIDlevel.csv',row.names=1))
hovon_entrez_df=t(read.csv('datasets/microarray/GSE19784HOVON65entrezIDlevel.csv',row.names=1))
uams_entrez_df=t(read.csv('datasets/microarray/GSE24080UAMSentrezIDlevel.csv',row.names=1))
mmrf_entrez_df=t(read.csv('datasets/microarray/GSE9782APEXentrezIDlevel_mas5.csv',row.names=1))

# %%
emtab_pca<-pca(emtab_entrez_df, ncomp=10,center=TRUE,scale=FALSE, max.iter=500)
plot(emtab_pca)
# Out:
# plot without title

# %%
uams_pca<-pca(uams_entrez_df, ncomp=10,center=TRUE,scale=FALSE, max.iter=500)
plot(uams_pca)
# Out:
# plot without title

# %%
mmrf_pca<-pca(mmrf_entrez_df, ncomp=10,center=TRUE,scale=FALSE, max.iter=500)
plot(mmrf_pca)

# %%
hovon_pca<-pca(hovon_entrez_df, ncomp=10,center=TRUE,scale=FALSE, max.iter=500)
plot(hovon_pca)
